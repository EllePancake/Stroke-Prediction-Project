# %%
import numpy as np 
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score

import optuna
from optuna.integration import LightGBMPruningCallback

from lightgbm import LGBMClassifier

import pickle

# %%
stroke_df_with_features = pd.read_csv('healthcare_stroke_data_clean_with_features.csv')

# %%
X_feat = stroke_df_with_features.drop('stroke', axis=1)
y_feat = stroke_df_with_features['stroke']

X_train_feat, X_test_feat, y_train_feat, y_test_feat = train_test_split(X_feat, y_feat, test_size=0.2, random_state=42, stratify=y_feat)

X_train_feat.shape, X_test_feat.shape, y_train_feat.shape, y_test_feat.shape
# Out:
# ((3927, 12), (982, 12), (3927,), (982,))

# %%
numerical_cols = ['age', 'avg_glucose_level', 'bmi']
categorical_cols_feat = ['gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'smoking_status', 'bmi_category', 'age_group']

# %%
numerical_transformer = Pipeline(steps=[
    ('scaler', MinMaxScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
    ('num', numerical_transformer, numerical_cols),
    ('cat', categorical_transformer, categorical_cols_feat)
])

lgbm_model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LGBMClassifier(class_weight="balanced",
            objective="binary", metric="binary_logloss",
            verbosity=-1))
])

# %%
def objective(trial):
    n_estimators = trial.suggest_int('classifier__n_estimators', 50, 250, step=20)
    max_depth = trial.suggest_int('classifier__max_depth', 3, 15)
    boosting_type = trial.suggest_categorical('classifier__boosting_type', ["gbdt"])
    lambda_l1 = trial.suggest_float('classifier__lambda_l1', 0.001, 10.0, log=True)
    lambda_l2 = trial.suggest_float('classifier__lambda_l2', 0.001, 10.0, log=True)
    num_leaves = trial.suggest_int('classifier__num_leaves', 10, 200)
    feature_fraction = trial.suggest_float('classifier__feature_fraction', 0.5, .8)
    bagging_fraction = trial.suggest_float('classifier__bagging_fraction', 0.5, .8)
    bagging_freq = trial.suggest_int('classifier__bagging_freq', 1, 7)
    min_child_samples = trial.suggest_int('classifier__min_child_samples', 30, 100)
    scale_pos_weight = trial.suggest_float('classifier__scale_pos_weight', 10, 50)
    learning_rate = trial.suggest_float('classifier__learning_rate', 0.01, 0.1)

    lgbm_model_pipeline.set_params(**{
    'classifier__n_estimators': n_estimators,
    'classifier__max_depth': max_depth,
    'classifier__boosting_type': boosting_type,
    'classifier__lambda_l1': lambda_l1,
    'classifier__lambda_l2': lambda_l2,
    'classifier__num_leaves': num_leaves,
    'classifier__feature_fraction': feature_fraction,
    'classifier__bagging_fraction': bagging_fraction,
    'classifier__bagging_freq': bagging_freq,
    'classifier__min_child_samples': min_child_samples,
    'classifier__scale_pos_weight': scale_pos_weight,
    'classifier__learning_rate': learning_rate
})

    scores = []
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for train_index, test_index in kf.split(X_train_feat, y_train_feat):
        X_train, X_val = X_train_feat.iloc[train_index], X_train_feat.iloc[test_index]
        y_train, y_val = y_train_feat.iloc[train_index], y_train_feat.iloc[test_index]


        lgbm_model_pipeline.fit(X_train_feat, y_train_feat)

        preds = lgbm_model_pipeline.predict(X_val)

        score = f1_score(y_val, preds)
        scores.append(score)

    return -np.mean(scores)

study = optuna.create_study(direction='maximize')

study.optimize(objective, n_trials=100)  

best_params = study.best_params
best_score = -study.best_value

print(best_params, best_score)
# Out:
# [I 2024-04-13 13:32:18,144] A new study created in memory with name: no-name-b45a4775-3d6c-4fd6-a1af-9aec29b9ffce
# [I 2024-04-13 13:32:18,913] Trial 0 finished with value: -0.295356812061124 and parameters: {'classifier__n_estimators': 190, 'classifier__max_depth': 6, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.025925774595176813, 'classifier__lambda_l2': 0.058240206973644605, 'classifier__num_leaves': 67, 'classifier__feature_fraction': 0.5974914582924447, 'classifier__bagging_fraction': 0.6975531233511453, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 66, 'classifier__scale_pos_weight': 30.283324258536716, 'classifier__learning_rate': 0.08010362031156919}. Best is trial 0 with value: -0.295356812061124.
# [I 2024-04-13 13:32:19,345] Trial 1 finished with value: -0.13918417913060646 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.02798096558071742, 'classifier__lambda_l2': 0.013212545909746125, 'classifier__num_leaves': 191, 'classifier__feature_fraction': 0.667289375153583, 'classifier__bagging_fraction': 0.5443718821928949, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 92, 'classifier__scale_pos_weight': 38.85267164116226, 'classifier__learning_rate': 0.01624351643583233}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:19,707] Trial 2 finished with value: -0.14670920367754592 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 6, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 1.1700767716698401, 'classifier__lambda_l2': 0.005069628069274836, 'classifier__num_leaves': 139, 'classifier__feature_fraction': 0.5685399483163092, 'classifier__bagging_fraction': 0.5092653445667372, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 67, 'classifier__scale_pos_weight': 27.87315329048788, 'classifier__learning_rate': 0.031772210108439516}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:20,354] Trial 3 finished with value: -0.2154457492464395 and parameters: {'classifier__n_estimators': 210, 'classifier__max_depth': 15, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.001231458740726421, 'classifier__lambda_l2': 6.479954962853865, 'classifier__num_leaves': 32, 'classifier__feature_fraction': 0.5696955008779654, 'classifier__bagging_fraction': 0.6878795770474762, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 82, 'classifier__scale_pos_weight': 33.27980570609493, 'classifier__learning_rate': 0.053298785622413664}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:21,137] Trial 4 finished with value: -0.2161466670531222 and parameters: {'classifier__n_estimators': 170, 'classifier__max_depth': 13, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.006339899309336213, 'classifier__lambda_l2': 0.5150435540891831, 'classifier__num_leaves': 113, 'classifier__feature_fraction': 0.621983852990426, 'classifier__bagging_fraction': 0.7225809906735798, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 52, 'classifier__scale_pos_weight': 32.98718924002907, 'classifier__learning_rate': 0.030009348417365286}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:21,661] Trial 5 finished with value: -0.25226713431172787 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 11, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.9828551444367027, 'classifier__lambda_l2': 0.05845140479746972, 'classifier__num_leaves': 167, 'classifier__feature_fraction': 0.6778042585698235, 'classifier__bagging_fraction': 0.639678403465918, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 30, 'classifier__scale_pos_weight': 35.4866545583911, 'classifier__learning_rate': 0.06963404676004718}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:21,969] Trial 6 finished with value: -0.20126625990425154 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 9, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.1640713760340308, 'classifier__lambda_l2': 0.2057406154759258, 'classifier__num_leaves': 139, 'classifier__feature_fraction': 0.708933671855715, 'classifier__bagging_fraction': 0.5627482841635614, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 50, 'classifier__scale_pos_weight': 34.321379632390574, 'classifier__learning_rate': 0.09204822298855746}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:22,294] Trial 7 finished with value: -0.19665803460950249 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 14, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0713015721662309, 'classifier__lambda_l2': 0.7831948546751903, 'classifier__num_leaves': 36, 'classifier__feature_fraction': 0.6204686557481097, 'classifier__bagging_fraction': 0.6474987793151876, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 32, 'classifier__scale_pos_weight': 42.341931008488345, 'classifier__learning_rate': 0.0800207220971259}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:22,656] Trial 8 finished with value: -0.16013514374410218 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 14, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.008302144662587364, 'classifier__lambda_l2': 0.4422231461806872, 'classifier__num_leaves': 140, 'classifier__feature_fraction': 0.605940978478069, 'classifier__bagging_fraction': 0.6315671504661254, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 94, 'classifier__scale_pos_weight': 26.080604574243363, 'classifier__learning_rate': 0.03923509366226289}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:23,059] Trial 9 finished with value: -0.2000428955993975 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 14, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.5644461966690982, 'classifier__lambda_l2': 0.011984763236316297, 'classifier__num_leaves': 103, 'classifier__feature_fraction': 0.5307160539192212, 'classifier__bagging_fraction': 0.6521114296192954, 'classifier__bagging_freq': 7, 'classifier__min_child_samples': 72, 'classifier__scale_pos_weight': 19.093540656603338, 'classifier__learning_rate': 0.0599876951605314}. Best is trial 1 with value: -0.13918417913060646.
# [I 2024-04-13 13:32:23,560] Trial 10 finished with value: -0.1342838328058365 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 5.283289115270463, 'classifier__lambda_l2': 0.0015750747270841096, 'classifier__num_leaves': 190, 'classifier__feature_fraction': 0.7571850751357247, 'classifier__bagging_fraction': 0.7938370238608176, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 98, 'classifier__scale_pos_weight': 49.17768629365865, 'classifier__learning_rate': 0.012963294962445176}. Best is trial 10 with value: -0.1342838328058365.
# [I 2024-04-13 13:32:24,068] Trial 11 finished with value: -0.13295820380784762 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 8.559445085097272, 'classifier__lambda_l2': 0.001079544670104049, 'classifier__num_leaves': 200, 'classifier__feature_fraction': 0.7975750210616015, 'classifier__bagging_fraction': 0.7992183655977896, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 49.21054470505443, 'classifier__learning_rate': 0.010661072221729476}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:24,573] Trial 12 finished with value: -0.13344300811374418 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 6.995439827542335, 'classifier__lambda_l2': 0.001026669182057716, 'classifier__num_leaves': 197, 'classifier__feature_fraction': 0.79771080463833, 'classifier__bagging_fraction': 0.7978439647607004, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 98, 'classifier__scale_pos_weight': 49.84056843398925, 'classifier__learning_rate': 0.01057819017111291}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:25,115] Trial 13 finished with value: -0.1339751626580032 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 9.717183650884573, 'classifier__lambda_l2': 0.0022847367382010674, 'classifier__num_leaves': 169, 'classifier__feature_fraction': 0.7838573251906601, 'classifier__bagging_fraction': 0.7832073103720774, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 84, 'classifier__scale_pos_weight': 49.92968203280009, 'classifier__learning_rate': 0.010859722075587474}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:25,830] Trial 14 finished with value: -0.18913099935647323 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 8, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 3.065107902046672, 'classifier__lambda_l2': 0.0010303245962949594, 'classifier__num_leaves': 196, 'classifier__feature_fraction': 0.7401179672919064, 'classifier__bagging_fraction': 0.7565490370983294, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 82, 'classifier__scale_pos_weight': 43.43569993108252, 'classifier__learning_rate': 0.0252813555275887}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:26,226] Trial 15 finished with value: -0.15201810016972092 and parameters: {'classifier__n_estimators': 150, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 2.1482065732502655, 'classifier__lambda_l2': 0.009845122871984083, 'classifier__num_leaves': 170, 'classifier__feature_fraction': 0.7992682725144834, 'classifier__bagging_fraction': 0.7401925973157927, 'classifier__bagging_freq': 5, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 45.222780422627444, 'classifier__learning_rate': 0.0394223342356897}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:26,928] Trial 16 finished with value: -0.20673172519334754 and parameters: {'classifier__n_estimators': 210, 'classifier__max_depth': 7, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.30275158837998234, 'classifier__lambda_l2': 0.005008763366177796, 'classifier__num_leaves': 102, 'classifier__feature_fraction': 0.7255090597366808, 'classifier__bagging_fraction': 0.7978694705057968, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 88, 'classifier__scale_pos_weight': 10.550669636022164, 'classifier__learning_rate': 0.0217319083630551}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:27,332] Trial 17 finished with value: -0.16806277713514556 and parameters: {'classifier__n_estimators': 130, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 8.520174179052969, 'classifier__lambda_l2': 0.029561414798468463, 'classifier__num_leaves': 75, 'classifier__feature_fraction': 0.7702692221436725, 'classifier__bagging_fraction': 0.7641168264522378, 'classifier__bagging_freq': 5, 'classifier__min_child_samples': 76, 'classifier__scale_pos_weight': 39.81726248718134, 'classifier__learning_rate': 0.04564654723874732}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:27,928] Trial 18 finished with value: -0.16320227418522618 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 10, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 2.8200615197004915, 'classifier__lambda_l2': 0.00319637328107294, 'classifier__num_leaves': 10, 'classifier__feature_fraction': 0.7027673487206674, 'classifier__bagging_fraction': 0.7235788312873969, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 54, 'classifier__scale_pos_weight': 44.79291291203946, 'classifier__learning_rate': 0.021241146535709257}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:28,400] Trial 19 finished with value: -0.16446465236286692 and parameters: {'classifier__n_estimators': 190, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.4803504908418084, 'classifier__lambda_l2': 0.0011472615397908473, 'classifier__num_leaves': 157, 'classifier__feature_fraction': 0.7563595702820931, 'classifier__bagging_fraction': 0.6867250250991959, 'classifier__bagging_freq': 5, 'classifier__min_child_samples': 90, 'classifier__scale_pos_weight': 21.59125787559292, 'classifier__learning_rate': 0.035271151170894806}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:29,049] Trial 20 finished with value: -0.21718766209483825 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 1.6055803791650702, 'classifier__lambda_l2': 7.006552092941068, 'classifier__num_leaves': 197, 'classifier__feature_fraction': 0.7954429571587187, 'classifier__bagging_fraction': 0.606600652402926, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 41, 'classifier__scale_pos_weight': 47.63650252792185, 'classifier__learning_rate': 0.05091075978352728}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:29,569] Trial 21 finished with value: -0.1339751626580032 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 9.333519791877444, 'classifier__lambda_l2': 0.0022444052056356176, 'classifier__num_leaves': 175, 'classifier__feature_fraction': 0.7830483820055713, 'classifier__bagging_fraction': 0.7766160383337377, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 83, 'classifier__scale_pos_weight': 49.8274901844262, 'classifier__learning_rate': 0.010030619286383479}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:30,124] Trial 22 finished with value: -0.13636977374521136 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 4.930301627637526, 'classifier__lambda_l2': 0.0032129917381012274, 'classifier__num_leaves': 178, 'classifier__feature_fraction': 0.7719701041811756, 'classifier__bagging_fraction': 0.7841244656258376, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 97, 'classifier__scale_pos_weight': 46.665337132674125, 'classifier__learning_rate': 0.011193351232764595}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:30,697] Trial 23 finished with value: -0.168589920949145 and parameters: {'classifier__n_estimators': 210, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 4.633942463912447, 'classifier__lambda_l2': 0.00807613208444557, 'classifier__num_leaves': 158, 'classifier__feature_fraction': 0.7407571019799597, 'classifier__bagging_fraction': 0.7489333872090334, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 86, 'classifier__scale_pos_weight': 41.095337665063454, 'classifier__learning_rate': 0.02910116163495859}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:31,259] Trial 24 finished with value: -0.15454910151651174 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 7, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 8.417728118304574, 'classifier__lambda_l2': 0.0010280463688732498, 'classifier__num_leaves': 182, 'classifier__feature_fraction': 0.7955358593200768, 'classifier__bagging_fraction': 0.7979462915279503, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 49.61691068768541, 'classifier__learning_rate': 0.01868039223380801}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:31,750] Trial 25 finished with value: -0.13805482729353072 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 1.1212519662549925, 'classifier__lambda_l2': 0.01936454243918543, 'classifier__num_leaves': 154, 'classifier__feature_fraction': 0.7048106933588961, 'classifier__bagging_fraction': 0.7270022894775198, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 76, 'classifier__scale_pos_weight': 37.68373841035672, 'classifier__learning_rate': 0.01973777693154759}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:32,344] Trial 26 finished with value: -0.1700509351378768 and parameters: {'classifier__n_estimators': 190, 'classifier__max_depth': 6, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 3.206130833867409, 'classifier__lambda_l2': 0.002812345874264945, 'classifier__num_leaves': 200, 'classifier__feature_fraction': 0.7566954223554387, 'classifier__bagging_fraction': 0.7668298804720919, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 93, 'classifier__scale_pos_weight': 46.37161214677778, 'classifier__learning_rate': 0.026799476050900946}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:32,837] Trial 27 finished with value: -0.13616372258191345 and parameters: {'classifier__n_estimators': 210, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 8.6708092957114, 'classifier__lambda_l2': 0.00560954983655714, 'classifier__num_leaves': 121, 'classifier__feature_fraction': 0.7293527322158568, 'classifier__bagging_fraction': 0.7082150426717367, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 88, 'classifier__scale_pos_weight': 43.265776629493445, 'classifier__learning_rate': 0.015383583768219179}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:33,558] Trial 28 finished with value: -0.25440606589456116 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.585482899439779, 'classifier__lambda_l2': 0.0016845488664964973, 'classifier__num_leaves': 183, 'classifier__feature_fraction': 0.77443854755382, 'classifier__bagging_fraction': 0.7760366465381382, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 76, 'classifier__scale_pos_weight': 12.680431304837096, 'classifier__learning_rate': 0.04463920212247089}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:34,124] Trial 29 finished with value: -0.2540556883523703 and parameters: {'classifier__n_estimators': 170, 'classifier__max_depth': 7, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 1.97519098730946, 'classifier__lambda_l2': 0.04350632132854426, 'classifier__num_leaves': 126, 'classifier__feature_fraction': 0.6796327282621317, 'classifier__bagging_fraction': 0.6718558491326996, 'classifier__bagging_freq': 5, 'classifier__min_child_samples': 95, 'classifier__scale_pos_weight': 47.24424309583335, 'classifier__learning_rate': 0.09806224754008123}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:34,668] Trial 30 finished with value: -0.18383566976997698 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.11561419325815249, 'classifier__lambda_l2': 0.10142964122074685, 'classifier__num_leaves': 148, 'classifier__feature_fraction': 0.6472082842379488, 'classifier__bagging_fraction': 0.7452240746231723, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 61, 'classifier__scale_pos_weight': 29.677627265637376, 'classifier__learning_rate': 0.06624348367986696}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:35,252] Trial 31 finished with value: -0.1339220443732409 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 9.346954736433743, 'classifier__lambda_l2': 0.0019881957473657894, 'classifier__num_leaves': 170, 'classifier__feature_fraction': 0.782212562913553, 'classifier__bagging_fraction': 0.7758681699111415, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 84, 'classifier__scale_pos_weight': 49.79989941927739, 'classifier__learning_rate': 0.010533677732210738}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:35,831] Trial 32 finished with value: -0.15390809510901113 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 6, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 5.567455373852349, 'classifier__lambda_l2': 0.0027462538145206256, 'classifier__num_leaves': 167, 'classifier__feature_fraction': 0.7995979981044927, 'classifier__bagging_fraction': 0.7761728477389992, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 84, 'classifier__scale_pos_weight': 47.62309499382647, 'classifier__learning_rate': 0.015670323351124543}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:36,341] Trial 33 finished with value: -0.13333439379300782 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 9.946403385009535, 'classifier__lambda_l2': 0.005514974972931099, 'classifier__num_leaves': 187, 'classifier__feature_fraction': 0.7746951293893511, 'classifier__bagging_fraction': 0.7987897734549072, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 91, 'classifier__scale_pos_weight': 49.848234329010886, 'classifier__learning_rate': 0.010627921258914751}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:36,879] Trial 34 finished with value: -0.15184513798360605 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 4.160145991541131, 'classifier__lambda_l2': 0.005153909033938708, 'classifier__num_leaves': 187, 'classifier__feature_fraction': 0.753025874578914, 'classifier__bagging_fraction': 0.7996798499319484, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 91, 'classifier__scale_pos_weight': 44.26806997205563, 'classifier__learning_rate': 0.023636925512452105}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:37,391] Trial 35 finished with value: -0.14814921842258905 and parameters: {'classifier__n_estimators': 210, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.045457121907033694, 'classifier__lambda_l2': 2.7083636660513513, 'classifier__num_leaves': 187, 'classifier__feature_fraction': 0.7743924958672533, 'classifier__bagging_fraction': 0.7579158539807102, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 95, 'classifier__scale_pos_weight': 36.89170496084004, 'classifier__learning_rate': 0.016609417020281902}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:37,808] Trial 36 finished with value: -0.15581891230119407 and parameters: {'classifier__n_estimators': 170, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.012247178603351604, 'classifier__lambda_l2': 0.0016448599351346726, 'classifier__num_leaves': 197, 'classifier__feature_fraction': 0.73224529221343, 'classifier__bagging_fraction': 0.5735514906354511, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 79, 'classifier__scale_pos_weight': 41.50650954301423, 'classifier__learning_rate': 0.03333901830037488}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:38,529] Trial 37 finished with value: -0.15727442324570973 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 12, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0018073231264200227, 'classifier__lambda_l2': 0.015815548382868482, 'classifier__num_leaves': 179, 'classifier__feature_fraction': 0.5713486768798, 'classifier__bagging_fraction': 0.5020136627952734, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 91, 'classifier__scale_pos_weight': 45.39649351170854, 'classifier__learning_rate': 0.01659888698906385}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:39,110] Trial 38 finished with value: -0.18553746761396556 and parameters: {'classifier__n_estimators': 190, 'classifier__max_depth': 6, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 1.4632126175843159, 'classifier__lambda_l2': 0.006285843434139307, 'classifier__num_leaves': 89, 'classifier__feature_fraction': 0.7182003163180618, 'classifier__bagging_fraction': 0.7337573940987977, 'classifier__bagging_freq': 4, 'classifier__min_child_samples': 67, 'classifier__scale_pos_weight': 39.419444146847184, 'classifier__learning_rate': 0.02634458424403057}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:39,636] Trial 39 finished with value: -0.23385293073938854 and parameters: {'classifier__n_estimators': 130, 'classifier__max_depth': 9, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.9603675679656692, 'classifier__lambda_l2': 0.003851282557615777, 'classifier__num_leaves': 160, 'classifier__feature_fraction': 0.6855734936034263, 'classifier__bagging_fraction': 0.7076692381180066, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 97, 'classifier__scale_pos_weight': 48.18448883296695, 'classifier__learning_rate': 0.08054813733401318}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:40,154] Trial 40 finished with value: -0.14465291115006734 and parameters: {'classifier__n_estimators': 210, 'classifier__max_depth': 8, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 2.5844361899956403, 'classifier__lambda_l2': 0.0014878556495733566, 'classifier__num_leaves': 145, 'classifier__feature_fraction': 0.6544818759876913, 'classifier__bagging_fraction': 0.5345812918842914, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 72, 'classifier__scale_pos_weight': 24.780754810288457, 'classifier__learning_rate': 0.010272180599310241}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:40,750] Trial 41 finished with value: -0.13744384090386313 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 6.069317983380101, 'classifier__lambda_l2': 0.00200859879436593, 'classifier__num_leaves': 166, 'classifier__feature_fraction': 0.783781185421488, 'classifier__bagging_fraction': 0.7827218652476986, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 87, 'classifier__scale_pos_weight': 49.81624923403139, 'classifier__learning_rate': 0.010103852442250932}. Best is trial 11 with value: -0.13295820380784762.
# [I 2024-04-13 13:32:41,281] Trial 42 finished with value: -0.13220814294519495 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 9.823376685550553, 'classifier__lambda_l2': 0.0021273794573622904, 'classifier__num_leaves': 129, 'classifier__feature_fraction': 0.5008139364838473, 'classifier__bagging_fraction': 0.7847998547626325, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 93, 'classifier__scale_pos_weight': 46.36279384609291, 'classifier__learning_rate': 0.015551168031275344}. Best is trial 42 with value: -0.13220814294519495.
# [I 2024-04-13 13:32:41,814] Trial 43 finished with value: -0.1398112679510169 and parameters: {'classifier__n_estimators': 230, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 3.6223067889357794, 'classifier__lambda_l2': 0.0010600111685195378, 'classifier__num_leaves': 124, 'classifier__feature_fraction': 0.5553713178874609, 'classifier__bagging_fraction': 0.7674626102381576, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 93, 'classifier__scale_pos_weight': 46.43697876196732, 'classifier__learning_rate': 0.01972086705413517}. Best is trial 42 with value: -0.13220814294519495.
# [I 2024-04-13 13:32:42,359] Trial 44 finished with value: -0.1317016561534472 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 6.5045132900205065, 'classifier__lambda_l2': 0.004029312646043257, 'classifier__num_leaves': 189, 'classifier__feature_fraction': 0.527966509741889, 'classifier__bagging_fraction': 0.7861310037041843, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 42.809884709582185, 'classifier__learning_rate': 0.014382157964889215}. Best is trial 44 with value: -0.1317016561534472.
# [I 2024-04-13 13:32:42,892] Trial 45 finished with value: -0.13308537513520471 and parameters: {'classifier__n_estimators': 250, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 5.997073514780951, 'classifier__lambda_l2': 0.00779259701683995, 'classifier__num_leaves': 132, 'classifier__feature_fraction': 0.5032046943415733, 'classifier__bagging_fraction': 0.7879529735846316, 'classifier__bagging_freq': 3, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 42.66849215110973, 'classifier__learning_rate': 0.015431531975584062}. Best is trial 44 with value: -0.1317016561534472.
# [I 2024-04-13 13:32:43,193] Trial 46 finished with value: -0.13164153713587257 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 5.397530690611942, 'classifier__lambda_l2': 0.025082659148395237, 'classifier__num_leaves': 131, 'classifier__feature_fraction': 0.508238404736979, 'classifier__bagging_fraction': 0.7531429332201188, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 32.559937514477596, 'classifier__learning_rate': 0.03133753421291036}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:43,512] Trial 47 finished with value: -0.13204460459550088 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.8108617392928336, 'classifier__lambda_l2': 0.030120404312956157, 'classifier__num_leaves': 133, 'classifier__feature_fraction': 0.5067720286593553, 'classifier__bagging_fraction': 0.7516991561726032, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 34.823297179648975, 'classifier__learning_rate': 0.03556915773755006}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:43,821] Trial 48 finished with value: -0.13259363989479073 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.26594817056703285, 'classifier__lambda_l2': 0.09630351801969912, 'classifier__num_leaves': 97, 'classifier__feature_fraction': 0.5017446568644383, 'classifier__bagging_fraction': 0.7522890290846208, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 96, 'classifier__scale_pos_weight': 30.774971648025936, 'classifier__learning_rate': 0.03790615360380532}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:44,116] Trial 49 finished with value: -0.13288674590594932 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.24558454148666695, 'classifier__lambda_l2': 0.17953422331165358, 'classifier__num_leaves': 111, 'classifier__feature_fraction': 0.5043922427670591, 'classifier__bagging_fraction': 0.7029036749764758, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 96, 'classifier__scale_pos_weight': 33.821848523439805, 'classifier__learning_rate': 0.03809363505395805}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:44,434] Trial 50 finished with value: -0.13259146070140793 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.22845892031513407, 'classifier__lambda_l2': 0.0601521555177839, 'classifier__num_leaves': 90, 'classifier__feature_fraction': 0.5214479051082065, 'classifier__bagging_fraction': 0.750894152005154, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 61, 'classifier__scale_pos_weight': 30.891163968062944, 'classifier__learning_rate': 0.04354729722766252}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:44,761] Trial 51 finished with value: -0.13243665560647871 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.1934985708185505, 'classifier__lambda_l2': 0.06557394860687488, 'classifier__num_leaves': 90, 'classifier__feature_fraction': 0.5221828052787567, 'classifier__bagging_fraction': 0.745626076258754, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 59, 'classifier__scale_pos_weight': 30.879430414919664, 'classifier__learning_rate': 0.04404767944570214}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:45,071] Trial 52 finished with value: -0.13354751677289384 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.13210969418096571, 'classifier__lambda_l2': 0.025177496481491538, 'classifier__num_leaves': 62, 'classifier__feature_fraction': 0.5239038547381004, 'classifier__bagging_fraction': 0.7191248609410141, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 60, 'classifier__scale_pos_weight': 31.75902435013312, 'classifier__learning_rate': 0.04884361901873179}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:45,446] Trial 53 finished with value: -0.14795725213845687 and parameters: {'classifier__n_estimators': 110, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.08068451995190154, 'classifier__lambda_l2': 0.051437425044811816, 'classifier__num_leaves': 79, 'classifier__feature_fraction': 0.5269026059363912, 'classifier__bagging_fraction': 0.7389022165095781, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 56, 'classifier__scale_pos_weight': 29.117783945971304, 'classifier__learning_rate': 0.0551959539211092}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:45,748] Trial 54 finished with value: -0.1361093288473017 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.7275955315074352, 'classifier__lambda_l2': 0.08316363241380136, 'classifier__num_leaves': 62, 'classifier__feature_fraction': 0.5519176664290495, 'classifier__bagging_fraction': 0.6862541496145829, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 46, 'classifier__scale_pos_weight': 27.193014498949758, 'classifier__learning_rate': 0.030902220242232523}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:46,149] Trial 55 finished with value: -0.14970109058718617 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.44772258259847336, 'classifier__lambda_l2': 0.16229974062500307, 'classifier__num_leaves': 92, 'classifier__feature_fraction': 0.5182468510319248, 'classifier__bagging_fraction': 0.757798104418481, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 64, 'classifier__scale_pos_weight': 32.20151361036653, 'classifier__learning_rate': 0.04307854831017703}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:46,473] Trial 56 finished with value: -0.1363760593453663 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.18783938278962523, 'classifier__lambda_l2': 0.2974317441470103, 'classifier__num_leaves': 85, 'classifier__feature_fraction': 0.5413974748646655, 'classifier__bagging_fraction': 0.7353508807028153, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 49, 'classifier__scale_pos_weight': 34.94927490626531, 'classifier__learning_rate': 0.05862931289203967}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:46,851] Trial 57 finished with value: -0.1531406308983333 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 15, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.033376903942159745, 'classifier__lambda_l2': 0.028641312231953046, 'classifier__num_leaves': 114, 'classifier__feature_fraction': 0.5147093687870596, 'classifier__bagging_fraction': 0.7177621579706599, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 58, 'classifier__scale_pos_weight': 36.38264356519413, 'classifier__learning_rate': 0.04182079075412132}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:47,217] Trial 58 finished with value: -0.13482824954373404 and parameters: {'classifier__n_estimators': 110, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.32586701954424535, 'classifier__lambda_l2': 0.07147693599518387, 'classifier__num_leaves': 137, 'classifier__feature_fraction': 0.5808346019024485, 'classifier__bagging_fraction': 0.7485056245732159, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 62, 'classifier__scale_pos_weight': 23.688328108340144, 'classifier__learning_rate': 0.0331264400953398}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:47,747] Trial 59 finished with value: -0.20815788631100968 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 11, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.06417723535969265, 'classifier__lambda_l2': 0.04254003584724357, 'classifier__num_leaves': 71, 'classifier__feature_fraction': 0.5370023318200283, 'classifier__bagging_fraction': 0.767833605804905, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 41, 'classifier__scale_pos_weight': 28.240259615238877, 'classifier__learning_rate': 0.047952463847284375}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:48,062] Trial 60 finished with value: -0.14580628298086432 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.1787598529498073, 'classifier__lambda_l2': 0.012848351080496694, 'classifier__num_leaves': 45, 'classifier__feature_fraction': 0.548247282939515, 'classifier__bagging_fraction': 0.6152712179837823, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 68, 'classifier__scale_pos_weight': 33.93166078001319, 'classifier__learning_rate': 0.03481036006166112}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:48,380] Trial 61 finished with value: -0.13316774604799314 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.3323639598937684, 'classifier__lambda_l2': 0.11902050531440811, 'classifier__num_leaves': 94, 'classifier__feature_fraction': 0.5110357747754461, 'classifier__bagging_fraction': 0.7524665922331971, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 98, 'classifier__scale_pos_weight': 31.15867108019645, 'classifier__learning_rate': 0.03797198886386928}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:48,716] Trial 62 finished with value: -0.13193382151020452 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.09791123570495917, 'classifier__lambda_l2': 0.2591331364728329, 'classifier__num_leaves': 100, 'classifier__feature_fraction': 0.5330379385160722, 'classifier__bagging_fraction': 0.7297571221659931, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 30.596645332005757, 'classifier__learning_rate': 0.029022450844229105}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:49,134] Trial 63 finished with value: -0.13888002615233738 and parameters: {'classifier__n_estimators': 110, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.017735085880066177, 'classifier__lambda_l2': 0.4989024383274248, 'classifier__num_leaves': 105, 'classifier__feature_fraction': 0.5303167354433879, 'classifier__bagging_fraction': 0.7635945123172332, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 100, 'classifier__scale_pos_weight': 26.745974821160516, 'classifier__learning_rate': 0.029151536285936037}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:49,434] Trial 64 finished with value: -0.13455179441850965 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.050193144189528, 'classifier__lambda_l2': 0.7596828267817721, 'classifier__num_leaves': 112, 'classifier__feature_fraction': 0.5592143950089046, 'classifier__bagging_fraction': 0.7287956909292683, 'classifier__bagging_freq': 7, 'classifier__min_child_samples': 55, 'classifier__scale_pos_weight': 32.700554278559665, 'classifier__learning_rate': 0.04063529835100025}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:49,803] Trial 65 finished with value: -0.13513097081744557 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.08166454283331089, 'classifier__lambda_l2': 0.2687223875120819, 'classifier__num_leaves': 132, 'classifier__feature_fraction': 0.5398672130708457, 'classifier__bagging_fraction': 0.6674608886343235, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 94, 'classifier__scale_pos_weight': 35.36322876118644, 'classifier__learning_rate': 0.023536778933919856}. Best is trial 46 with value: -0.13164153713587257.
# [I 2024-04-13 13:32:50,091] Trial 66 finished with value: -0.13154500470067637 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.1270316170846584, 'classifier__lambda_l2': 0.018538741450326753, 'classifier__num_leaves': 100, 'classifier__feature_fraction': 0.5879097428247246, 'classifier__bagging_fraction': 0.7870498014359322, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 52, 'classifier__scale_pos_weight': 28.881612187208162, 'classifier__learning_rate': 0.04663514880086294}. Best is trial 66 with value: -0.13154500470067637.
# [I 2024-04-13 13:32:50,412] Trial 67 finished with value: -0.14372478513358442 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 2.2366120686769477, 'classifier__lambda_l2': 0.040539019951485816, 'classifier__num_leaves': 118, 'classifier__feature_fraction': 0.6103823242215931, 'classifier__bagging_fraction': 0.7889744338764826, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 46, 'classifier__scale_pos_weight': 28.925367483496323, 'classifier__learning_rate': 0.05347059321003744}. Best is trial 66 with value: -0.13154500470067637.
# [I 2024-04-13 13:32:50,725] Trial 68 finished with value: -0.1412409956556125 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.09502183858826947, 'classifier__lambda_l2': 0.023925119941458652, 'classifier__num_leaves': 100, 'classifier__feature_fraction': 0.5888094557935649, 'classifier__bagging_fraction': 0.7777280556058127, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 53, 'classifier__scale_pos_weight': 22.07802554394714, 'classifier__learning_rate': 0.04703755377929931}. Best is trial 66 with value: -0.13154500470067637.
# [I 2024-04-13 13:32:51,080] Trial 69 finished with value: -0.13164245033423733 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.029817821291714692, 'classifier__lambda_l2': 0.010542373439078238, 'classifier__num_leaves': 83, 'classifier__feature_fraction': 0.5644756566192821, 'classifier__bagging_fraction': 0.7714817155382983, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 50, 'classifier__scale_pos_weight': 38.01399382169129, 'classifier__learning_rate': 0.027611436570163874}. Best is trial 66 with value: -0.13154500470067637.
# [I 2024-04-13 13:32:51,471] Trial 70 finished with value: -0.13965714589596787 and parameters: {'classifier__n_estimators': 90, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.014737236653619002, 'classifier__lambda_l2': 0.008424802702687069, 'classifier__num_leaves': 81, 'classifier__feature_fraction': 0.5643906202702546, 'classifier__bagging_fraction': 0.7729828830782441, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 37, 'classifier__scale_pos_weight': 38.47018716828532, 'classifier__learning_rate': 0.028229522131998287}. Best is trial 66 with value: -0.13154500470067637.
# [I 2024-04-13 13:32:51,789] Trial 71 finished with value: -0.13318150176763519 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.005496805135330489, 'classifier__lambda_l2': 0.015899398923944374, 'classifier__num_leaves': 108, 'classifier__feature_fraction': 0.5114279039656235, 'classifier__bagging_fraction': 0.7411270401809859, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 48, 'classifier__scale_pos_weight': 40.622497602587096, 'classifier__learning_rate': 0.023816287486808075}. Best is trial 66 with value: -0.13154500470067637.
# [I 2024-04-13 13:32:52,076] Trial 72 finished with value: -0.12976897410287944 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.13112042390600942, 'classifier__lambda_l2': 0.010992751243228996, 'classifier__num_leaves': 102, 'classifier__feature_fraction': 0.5358817518785215, 'classifier__bagging_fraction': 0.7887705363533121, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 98, 'classifier__scale_pos_weight': 36.60447339196213, 'classifier__learning_rate': 0.036274614915360305}. Best is trial 72 with value: -0.12976897410287944.
# [I 2024-04-13 13:32:52,386] Trial 73 finished with value: -0.1349301006008336 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.025559566073460657, 'classifier__lambda_l2': 0.010943686785071712, 'classifier__num_leaves': 118, 'classifier__feature_fraction': 0.5740554734041136, 'classifier__bagging_fraction': 0.7891124551909838, 'classifier__bagging_freq': 2, 'classifier__min_child_samples': 98, 'classifier__scale_pos_weight': 37.94652521522039, 'classifier__learning_rate': 0.03637572139874648}. Best is trial 72 with value: -0.12976897410287944.
# ...
# [I 2024-04-13 13:32:53,296] Trial 76 finished with value: -0.12361909385674408 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.12112651802305698, 'classifier__lambda_l2': 0.004119228198777714, 'classifier__num_leaves': 105, 'classifier__feature_fraction': 0.5466689572226212, 'classifier__bagging_fraction': 0.7632500492955392, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 89, 'classifier__scale_pos_weight': 36.507648352060656, 'classifier__learning_rate': 0.031000150145920405}. Best is trial 76 with value: -0.12361909385674408.
# [I 2024-04-13 13:32:53,632] Trial 77 finished with value: -0.13809726593274685 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.05697364778725338, 'classifier__lambda_l2': 0.00413443431574056, 'classifier__num_leaves': 105, 'classifier__feature_fraction': 0.5460808500760503, 'classifier__bagging_fraction': 0.7603548179067566, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 80, 'classifier__scale_pos_weight': 36.93278190117201, 'classifier__learning_rate': 0.032216141482825}. Best is trial 76 with value: -0.12361909385674408.
# [I 2024-04-13 13:32:53,931] Trial 78 finished with value: -0.1205293723563041 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0357863672300763, 'classifier__lambda_l2': 0.003857064597849829, 'classifier__num_leaves': 74, 'classifier__feature_fraction': 0.5594047353632459, 'classifier__bagging_fraction': 0.7696728842309242, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 89, 'classifier__scale_pos_weight': 39.78130890394614, 'classifier__learning_rate': 0.02594287887909834}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:54,235] Trial 79 finished with value: -0.1372811704673208 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.036216630707868486, 'classifier__lambda_l2': 0.007395383269331186, 'classifier__num_leaves': 49, 'classifier__feature_fraction': 0.591772904555344, 'classifier__bagging_fraction': 0.7706684091295409, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 89, 'classifier__scale_pos_weight': 39.46748305561267, 'classifier__learning_rate': 0.026084051254189663}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:54,524] Trial 80 finished with value: -0.1290618419192971 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.13737600413388787, 'classifier__lambda_l2': 0.016525783632988428, 'classifier__num_leaves': 84, 'classifier__feature_fraction': 0.5617175331727798, 'classifier__bagging_fraction': 0.7934348532170782, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 86, 'classifier__scale_pos_weight': 36.25437542812622, 'classifier__learning_rate': 0.021130580570404178}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:54,825] Trial 81 finished with value: -0.13299501577348244 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.13881962462152786, 'classifier__lambda_l2': 0.017613059519479488, 'classifier__num_leaves': 74, 'classifier__feature_fraction': 0.561871658216181, 'classifier__bagging_fraction': 0.7937128821962233, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 86, 'classifier__scale_pos_weight': 36.82134172881246, 'classifier__learning_rate': 0.032542536645199065}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:55,122] Trial 82 finished with value: -0.12136205235850532 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.02916796562163291, 'classifier__lambda_l2': 0.010147354027504888, 'classifier__num_leaves': 81, 'classifier__feature_fraction': 0.5816870313317564, 'classifier__bagging_fraction': 0.7795100323937421, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 90, 'classifier__scale_pos_weight': 36.01517961512678, 'classifier__learning_rate': 0.021395344808551712}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:55,441] Trial 83 finished with value: -0.1376130290393897 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.04188419660629454, 'classifier__lambda_l2': 0.006413433980741564, 'classifier__num_leaves': 66, 'classifier__feature_fraction': 0.5801930963867411, 'classifier__bagging_fraction': 0.7812657922894158, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 85, 'classifier__scale_pos_weight': 35.813081426382766, 'classifier__learning_rate': 0.021317265242707203}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:55,722] Trial 84 finished with value: -0.13347841983382258 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.022172392066285865, 'classifier__lambda_l2': 0.0027953408577841756, 'classifier__num_leaves': 97, 'classifier__feature_fraction': 0.6278420887126086, 'classifier__bagging_fraction': 0.7915139266166447, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 80, 'classifier__scale_pos_weight': 33.17742874758534, 'classifier__learning_rate': 0.024178972520030137}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:56,021] Trial 85 finished with value: -0.12325543737284783 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.008803724151771898, 'classifier__lambda_l2': 0.004348902164552167, 'classifier__num_leaves': 79, 'classifier__feature_fraction': 0.5528353749625681, 'classifier__bagging_fraction': 0.7621080763780899, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 89, 'classifier__scale_pos_weight': 40.30853808672584, 'classifier__learning_rate': 0.030546096463201184}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:56,317] Trial 86 finished with value: -0.13668493900028003 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.005399199557625504, 'classifier__lambda_l2': 0.004475053190115396, 'classifier__num_leaves': 55, 'classifier__feature_fraction': 0.6019879281543503, 'classifier__bagging_fraction': 0.7623574488840442, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 90, 'classifier__scale_pos_weight': 40.45665524046039, 'classifier__learning_rate': 0.018194998951859102}. Best is trial 78 with value: -0.1205293723563041.
# [I 2024-04-13 13:32:56,627] Trial 87 finished with value: -0.1196198043672082 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.008875619498587435, 'classifier__lambda_l2': 0.002955953094644471, 'classifier__num_leaves': 84, 'classifier__feature_fraction': 0.5556161994203535, 'classifier__bagging_fraction': 0.779655183282308, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 89, 'classifier__scale_pos_weight': 41.57987989081641, 'classifier__learning_rate': 0.025894777544426133}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:56,943] Trial 88 finished with value: -0.13428422653748512 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.008680626506373157, 'classifier__lambda_l2': 0.003252766764052226, 'classifier__num_leaves': 77, 'classifier__feature_fraction': 0.5560921642284244, 'classifier__bagging_fraction': 0.7772731588786727, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 88, 'classifier__scale_pos_weight': 41.87735373041388, 'classifier__learning_rate': 0.0212117495746175}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:57,299] Trial 89 finished with value: -0.14049477112095357 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 5, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0035211172893909884, 'classifier__lambda_l2': 0.003576594994885256, 'classifier__num_leaves': 87, 'classifier__feature_fraction': 0.5452354231619116, 'classifier__bagging_fraction': 0.7996765721573329, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 83, 'classifier__scale_pos_weight': 39.47201271159277, 'classifier__learning_rate': 0.025261222247997834}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:57,600] Trial 90 finished with value: -0.1294824122665063 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.008997071318460904, 'classifier__lambda_l2': 0.00250715861736015, 'classifier__num_leaves': 70, 'classifier__feature_fraction': 0.5727574109842657, 'classifier__bagging_fraction': 0.7674381282726689, 'classifier__bagging_freq': 1, 'classifier__min_child_samples': 92, 'classifier__scale_pos_weight': 38.744126992079295, 'classifier__learning_rate': 0.03448353439390375}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:57,917] Trial 91 finished with value: -0.12600133762906712 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.003503489342220977, 'classifier__lambda_l2': 0.002451305838395672, 'classifier__num_leaves': 69, 'classifier__feature_fraction': 0.5738834315574851, 'classifier__bagging_fraction': 0.7659674888738898, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 91, 'classifier__scale_pos_weight': 38.70563163941326, 'classifier__learning_rate': 0.0297464500473849}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:58,209] Trial 92 finished with value: -0.12461195854709813 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0031693463019356253, 'classifier__lambda_l2': 0.0014344494415550553, 'classifier__num_leaves': 71, 'classifier__feature_fraction': 0.5714666961421538, 'classifier__bagging_fraction': 0.7629859192162037, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 91, 'classifier__scale_pos_weight': 40.3932732228711, 'classifier__learning_rate': 0.03038618704714737}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:58,594] Trial 93 finished with value: -0.1450941733045442 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 13, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.002216624084223944, 'classifier__lambda_l2': 0.0013536093296187001, 'classifier__num_leaves': 64, 'classifier__feature_fraction': 0.5802315404025152, 'classifier__bagging_fraction': 0.7587362422908825, 'classifier__bagging_freq': 7, 'classifier__min_child_samples': 89, 'classifier__scale_pos_weight': 40.345612479455475, 'classifier__learning_rate': 0.030720098226003023}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:58,943] Trial 94 finished with value: -0.13805849014923718 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.002630303710546647, 'classifier__lambda_l2': 0.0018496260811015574, 'classifier__num_leaves': 73, 'classifier__feature_fraction': 0.5675167390044251, 'classifier__bagging_fraction': 0.7791309791959962, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 87, 'classifier__scale_pos_weight': 41.512794804679636, 'classifier__learning_rate': 0.022750561703257517}. Best is trial 87 with value: -0.1196198043672082.
# [I 2024-04-13 13:32:59,283] Trial 95 finished with value: -0.10898064673731041 and parameters: {'classifier__n_estimators': 50, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0010851309055639358, 'classifier__lambda_l2': 0.0012804686806582421, 'classifier__num_leaves': 81, 'classifier__feature_fraction': 0.5520958352842444, 'classifier__bagging_fraction': 0.7433232272382043, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 92, 'classifier__scale_pos_weight': 37.3483700960801, 'classifier__learning_rate': 0.01866394272821166}. Best is trial 95 with value: -0.10898064673731041.
# [I 2024-04-13 13:32:59,639] Trial 96 finished with value: -0.10572831706121406 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.00157319233985872, 'classifier__lambda_l2': 0.0015553217741865806, 'classifier__num_leaves': 58, 'classifier__feature_fraction': 0.5512706551945784, 'classifier__bagging_fraction': 0.7448608103450373, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 92, 'classifier__scale_pos_weight': 44.2729906111573, 'classifier__learning_rate': 0.012953028610957897}. Best is trial 96 with value: -0.10572831706121406.
# [I 2024-04-13 13:33:00,027] Trial 97 finished with value: -0.13247750433441188 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 4, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0015253741129114373, 'classifier__lambda_l2': 0.0012832562737121753, 'classifier__num_leaves': 58, 'classifier__feature_fraction': 0.5519067431893372, 'classifier__bagging_fraction': 0.7436284508186793, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 92, 'classifier__scale_pos_weight': 43.073664248205475, 'classifier__learning_rate': 0.013490611238958814}. Best is trial 96 with value: -0.10572831706121406.
# [I 2024-04-13 13:33:00,384] Trial 98 finished with value: -0.11843454527767858 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0010329717314103224, 'classifier__lambda_l2': 0.002327281712447217, 'classifier__num_leaves': 68, 'classifier__feature_fraction': 0.5954199984972393, 'classifier__bagging_fraction': 0.7361105481297295, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 90, 'classifier__scale_pos_weight': 44.50882908270548, 'classifier__learning_rate': 0.019416256772407724}. Best is trial 96 with value: -0.10572831706121406.
# [I 2024-04-13 13:33:00,731] Trial 99 finished with value: -0.10942855590858847 and parameters: {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.0010618296230264807, 'classifier__lambda_l2': 0.0015484225901290266, 'classifier__num_leaves': 32, 'classifier__feature_fraction': 0.6132420784589742, 'classifier__bagging_fraction': 0.7363760774280751, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 94, 'classifier__scale_pos_weight': 44.50086816019894, 'classifier__learning_rate': 0.012622894862627769}. Best is trial 96 with value: -0.10572831706121406.
# {'classifier__n_estimators': 70, 'classifier__max_depth': 3, 'classifier__boosting_type': 'gbdt', 'classifier__lambda_l1': 0.00157319233985872, 'classifier__lambda_l2': 0.0015553217741865806, 'classifier__num_leaves': 58, 'classifier__feature_fraction': 0.5512706551945784, 'classifier__bagging_fraction': 0.7448608103450373, 'classifier__bagging_freq': 6, 'classifier__min_child_samples': 92, 'classifier__scale_pos_weight': 44.2729906111573, 'classifier__learning_rate': 0.012953028610957897} 0.10572831706121406

# %%
best_params = study.best_params

lgbm_model_pipeline.set_params(**{
    'classifier__n_estimators': best_params['classifier__n_estimators'],
    'classifier__max_depth': best_params['classifier__max_depth'],
    'classifier__boosting_type': best_params['classifier__boosting_type'],
    'classifier__lambda_l1': best_params['classifier__lambda_l1'],
    'classifier__lambda_l2': best_params['classifier__lambda_l2'],
    'classifier__num_leaves': best_params['classifier__num_leaves'],
    'classifier__feature_fraction': best_params['classifier__feature_fraction'],
    'classifier__bagging_fraction': best_params['classifier__bagging_fraction'],
    'classifier__bagging_freq': best_params['classifier__bagging_freq'],
    'classifier__min_child_samples': best_params['classifier__min_child_samples'],
    'classifier__scale_pos_weight': best_params['classifier__scale_pos_weight'],
    'classifier__learning_rate': best_params['classifier__learning_rate']
})

lgbm_model_pipeline.fit(X_train_feat, y_train_feat)

y_pred_feat = lgbm_model_pipeline.predict(X_test_feat)

# %%
# Save the model to a file
with open("model.pkl", "wb") as f:
    pickle.dump(lgbm_model_pipeline, f)
